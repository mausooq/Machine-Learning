# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('carprices.csv')
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
# %matplotlib inline
plt.scatter(df['Mileage'],df['Sell Price($)'],color='red',marker='*')

# %%
# %matplotlib inline
plt.scatter(df['Age(yrs)'],df['Sell Price($)'],color='red',marker='*')

# %%
X = df[['Mileage','Age(yrs)']]
Y = df['Sell Price($)']

# %%
from sklearn.model_selection import train_test_split

X_train , X_test ,Y_train ,Y_test = train_test_split(X,Y,train_size=0.8)

# %%
len(X_train)
# Out:
# 16

# %%
len(X_test)
# Out:
# 4

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 7     72000         6
# 5     59000         5
# 0     69000         6
# 9     67000         6
# 19    52000         5
# 10    83000         7
# 16    28000         2
# 18    87600         8
# 17    69000         5
# 11    79000         7
# 2     57000         5
# 1     35000         3
# 4     46000         4
# 8     91000         8
# 15    25400         3
# 14    82450         7

# %%
from sklearn import linear_model
clf = linear_model.LinearRegression()

clf.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
clf.predict(X_test)
# Out:
# array([24988.98582771, 37855.09198497, 25411.01866152, 27254.61232298])

# %%
Y_test
# Out:
# 12    26000
# 3     40000
# 13    27500
# 6     32000
# Name: Sell Price($), dtype: int64

# %%
clf.score(X_train,Y_train)
# Out:
# 0.9426997861032428
